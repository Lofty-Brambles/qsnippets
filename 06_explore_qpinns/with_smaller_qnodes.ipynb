# %% [markdown]
# # @TODO
#
# We have an approach explored in the notebooks to do most of our calculations in the QPU. Can we implement a singular Quantum node in between the two layers of the PINN? Is there an activation function that we can use to directly load the data in an easy fashion?
